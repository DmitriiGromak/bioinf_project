# %% [markdown]
# # Запускаем rust реализацию zhunt

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
# Out:
# info: downloading installer
# warn: It looks like you have an existing rustup settings file at:
# warn: /home/dgromak/.rustup/settings.toml
# warn: Rustup will install the default toolchain as specified in the settings file,
# warn: instead of the one inferred from the default host triple.
# info: profile set to default
# info: default host triple is x86_64-unknown-linux-gnu
# info: syncing channel updates for stable-x86_64-unknown-linux-gnu
# info: latest update on 2026-05-28 for version 1.96.0 (ac68faa20 2026-05-25)
# info: downloading 6 components
#         cargo downloading [#              ]   10.64 MiB (5.57 MiB/s, ETA: 2s)
#         cargo downloading [#              ]   10.64 MiB (5.57 MiB/s, ETA: 2s)
#         cargo downloading [#              ]   10.64 MiB (5.57 MiB/s, ETA: 2s)
#         cargo downloading [#              ]   10.64 MiB (1.55 MiB/s, ETA: 7s)
#         cargo downloading [#              ]   10.64 MiB (1.54 MiB/s, ETA: 7s)
# ...

# %%
# !git clone https://github.com/beldmian/zhunt.rs.git
# Out:
# Cloning into 'zhunt.rs'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 14 (delta 3), reused 13 (delta 2), pack-reused 0 (from 0)
# Receiving objects: 100% (14/14), 13.65 KiB | 367.00 KiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
import os
os.environ["PATH"] += ":$HOME/.cargo/bin"

# %%
# %%bash
# cd zhunt.rs
# export PATH="$PATH:$HOME/.cargo/bin"
# cargo build --release
# Out:
#     Updating crates.io index
# ...
#   Downloaded anstyle v1.0.10
#   Downloaded anstyle-parse v0.2.6
#   Downloaded anstyle-query v1.1.2
#   Downloaded anstream v0.6.18
#   Downloaded anyhow v1.0.98
#   Downloaded utf8parse v0.2.2
#   Downloaded crossbeam-deque v0.8.6
#   Downloaded heck v0.5.0
#   Downloaded rand_chacha v0.3.1
#   Downloaded cfg-if v1.0.0
#   Downloaded either v1.15.0
#   Downloaded colorchoice v1.0.3
#   Downloaded is_terminal_polyfill v1.70.1
#   Downloaded clap_lex v0.7.4
#   Downloaded strsim v0.11.1
#   Downloaded rand_core v0.6.4
#   Downloaded quote v1.0.40
#   Downloaded ppv-lite86 v0.2.21
#   Downloaded memmap2 v0.9.5
#   Downloaded unicode-ident v1.0.18
#   Downloaded getrandom v0.2.16
#   Downloaded crossbeam-utils v0.8.21
#   Downloaded clap_derive v4.5.32
#   Downloaded crossbeam-epoch v0.9.18
#   Downloaded clap v4.5.39
#   Downloaded proc-macro2 v1.0.95
#   Downloaded rayon-core v1.12.1
#   Downloaded rand v0.8.5
#   Downloaded clap_builder v4.5.39
# ...

# %%
# !./zhunt.rs/target/release/zhunt 12 8 12 GCF_024542735.1_iyBomHunt1.1_genomic.fna
# Out:
# dinucleotides 12
# min/max 8 12
# operating on GCF_024542735.1_iyBomHunt1.1_genomic.fna
# Using 64 threads (auto-detected)
# Calculating zscore with multithreading
# Inputting sequence from GCF_024542735.1_iyBomHunt1.1_genomic.fna
# Loaded 317408543 nucleotides
# Processed 20000/317408543 positions
# Processed 40000/317408543 positions
# Processed 60000/317408543 positions
# Processed 80000/317408543 positions
# Processed 100000/317408543 positions
# Processed 120000/317408543 positions
# Processed 140000/317408543 positions
# Processed 160000/317408543 positions
# Processed 180000/317408543 positions
# Processed 200000/317408543 positions
# Processed 220000/317408543 positions
# Processed 240000/317408543 positions
# Processed 260000/317408543 positions
# Processed 280000/317408543 positions
# Processed 300000/317408543 positions
# Processed 320000/317408543 positions
# Processed 340000/317408543 positions
# Processed 360000/317408543 positions
# ...

# %%
# !awk '$6 > 400 {print $1 "\t" $2}' GCF_024542735.1_iyBomHunt1.1_genomic.fna.Z-SCORE > BomHunt_zhunt_unfiltered.tsv
